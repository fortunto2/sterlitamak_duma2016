# %%
# -*- coding: utf-8 -*-
from __future__ import unicode_literals

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Данные
# загружаем данные по стерлитамаку

# %%
data = pd.read_csv('str_mini.csv', encoding='utf-8')
data.rename(columns=lambda x: x[5:], inplace=True)

# %%
data.head()
# Out:
#     642  643  644  645  646  647  648  649  650  651  ...   748  749  750  \
# 0     0    4    4    2    4    0    0    3   20    3  ...     1    0    0
# 1     2    9    3    4    6    0    2    5   36    2  ...     2    0    0
# 2     2    3    5    5    2    0    6    6   10    3  ...     3   15    0
# 3  1101  788  994  998  881  434  789  563  801  480  ...   566  828    5
# 4    10    2    4    7    3    0    3    0   27    0  ...     5   10    0
#
#    751  752  753  3460  3461  3495  3496
# 0    0    0    0     0     1     2     0
# 1    6    0    4     6     0     4     0
# 2    3    0    0     2     2     0     0
# 3  458   13   68   554   392    50    69
# 4    1    0    1     4     0     3     0
#
# [5 rows x 116 columns]

# %%
golosa = data.sum().reset_index()
golosa = golosa.set_index('index')
golosa.head()
# Out:
#           0
# index
# 642    1999
# 643    1428
# 644    1806
# 645    1807
# 646    1601

# %%
golosaplot = golosa.hist()
# golosaplot.set_title(u"Kolichestvo Golosov po uchastkam")

# %% [markdown]
# Распределение голосов по участкам, Медиана: 1254 голоса на участке, в среднем 469 голоса на участок

# %%
# data = data[data>50]
# data.head()

# %%
data_percent = data.apply(lambda x: (x*100 / x.sum()))
data_percent.head(115)
# Out:
#           642        643        644        645        646        647  \
# 0    0.000000   0.280112   0.221484   0.110681   0.249844   0.000000
# 1    0.100050   0.630252   0.166113   0.221361   0.374766   0.000000
# 2    0.100050   0.210084   0.276855   0.276702   0.124922   0.000000
# 3   55.077539  55.182073  55.038760  55.229662  55.028107  58.255034
# 4    0.500250   0.140056   0.221484   0.387382   0.187383   0.000000
# 5    0.000000   0.070028   0.055371   0.055340   0.249844   2.013423
# 6    3.401701   2.871148   3.045404   3.099059   2.998126   2.953020
# 7    0.100050   0.140056   0.055371   0.000000   0.124922   0.000000
# 8    0.000000   0.070028   0.000000   0.110681   0.312305   0.000000
# 9    0.000000   0.140056   0.055371   0.110681   0.187383   0.000000
# 10   0.600300   0.420168   0.332226   0.110681   0.124922   2.013423
# 11  31.115558  30.672269  31.063123  31.267294  30.980637  27.919463
# 12   0.000000   0.140056   0.442968   0.110681   0.062461   0.939597
# 13   9.004502   9.033613   9.025471   8.909795   8.994379   5.906040
#
#           648        649        650        651    ...            748  \
# 0    0.000000   0.292683   1.233046   0.344037    ...       0.097276
# 1    0.139665   0.487805   2.219482   0.229358    ...       0.194553
# 2    0.418994   0.585366   0.616523   0.344037    ...       0.291829
# 3   55.097765  54.926829  49.383477  55.045872    ...      55.058366
# 4    0.209497   0.000000   1.664612   0.000000    ...       0.486381
# 5    0.209497   0.390244   0.123305   0.000000    ...       0.097276
# 6    3.002793   3.024390   2.589396   3.555046    ...       3.015564
# 7    0.139665   0.000000   0.493218   0.000000    ...       0.097276
# 8    0.209497   0.195122   0.554871   0.000000    ...       0.097276
# 9    0.139665   0.000000   0.061652   0.229358    ...       0.097276
# 10   0.209497   0.195122   0.739827   0.229358    ...       0.194553
# 11  30.935754  30.926829  31.134402  31.077982    ...      31.031128
# 12   0.209497   0.000000   0.123305   0.344037    ...       0.194553
# 13   9.078212   8.975610   9.062885   8.600917    ...       9.046693
#
#           749        750        751        752        753       3460  \
# 0    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 1    0.000000   0.000000   1.081081   0.000000   3.636364   0.595238
# 2    1.016949   0.000000   0.540541   0.000000   0.000000   0.198413
# 3   56.135593  55.555556  82.522523  86.666667  61.818182  54.960317
# 4    0.677966   0.000000   0.180180   0.000000   0.909091   0.396825
# 5    0.000000   0.000000   0.000000   0.000000   0.909091   0.099206
# 6    2.169492   0.000000   3.063063   6.666667  15.454545   2.976190
# 7    0.000000   0.000000   0.180180   0.000000   0.909091   0.000000
# 8    0.000000   0.000000   0.180180   0.000000   0.000000   0.198413
# 9    0.000000   0.000000   0.000000   0.000000   0.000000   0.396825
# 10   0.000000   0.000000   0.180180   0.000000   0.909091   0.000000
# 11  30.915254  33.333333   6.306306   6.666667  12.727273  30.952381
# 12   0.949153   0.000000   0.000000   0.000000   0.000000   0.297619
# 13   8.135593  11.111111   5.765766   0.000000   2.727273   8.928571
#
#          3461       3495       3496
# 0    0.142653   2.352941   0.000000
# 1    0.000000   4.705882   0.000000
# 2    0.285307   0.000000   0.000000
# 3   55.920114  58.823529  56.557377
# 4    0.000000   3.529412   0.000000
# 5    0.000000   0.000000   0.000000
# 6    3.138374  14.117647   3.278689
# 7    0.000000   0.000000   0.000000
# 8    0.142653   0.000000   0.000000
# 9    0.000000   0.000000   0.000000
# 10   0.000000   1.176471   0.819672
# 11  31.241084  12.941176  30.327869
# 12   0.000000   0.000000   0.000000
# 13   9.129815   2.352941   9.016393
#
# [14 rows x 116 columns]

# %%
edro = data_percent.transpose()[[3]]
edro = edro.sort_values(by=[3], ascending=[True])
edro = edro.rename(columns={3: 'EDRO'})
partii=edro
partii['KOMMUNISTY']=data_percent.transpose()[[11]]
partii['SPRAV_RUS']=data_percent.transpose()[[13]]
partii['LDPR']=data_percent.transpose()[[6]]
partii['PROSTA']=data_percent.transpose()[[8]]
partii['YABLOKO']=data_percent.transpose()[[10]]
partii.head()
# Out:
#           EDRO  KOMMUNISTY  SPRAV_RUS       LDPR    PROSTA   YABLOKO
# 736  42.424242   20.959596   2.525253  14.393939  2.020202  1.010101
# 650  49.383477   31.134402   9.062885   2.589396  0.554871  0.739827
# 716  51.708218   31.578947   3.416436   7.663897  0.092336  0.461681
# 670  52.500000   29.880952   5.714286   6.309524  0.000000  0.238095
# 654  53.531599   31.598513   9.169765   2.850062  0.619579  0.000000

# %% [markdown]
# ### Участки с большими процентами за едро
# http://www.bashkortostan.vybory.izbirkom.ru/bashkortostan/ik/4024049178662

# %%
partii.hist(figsize=(15,7))
plt.title('Histogram for EDRO')

# %% [markdown]
# Гистограма показывает что на большинстве участков близкое значение в 56%

# %%
partii.plot(title=u'Проценты за ЕДРО по участкам (56% в среднем)',figsize=(20,10))

# %% [markdown]
# Медиана в 56% почти на всех участках... причем настолько ровное распределение соотношения голосов за Единую России, вызывает удивление.

# %%
partii['golosa']=golosa
partii.head()
# Out:
#           EDRO  KOMMUNISTY  SPRAV_RUS       LDPR    PROSTA   YABLOKO  golosa
# 736  42.424242   20.959596   2.525253  14.393939  2.020202  1.010101     396
# 650  49.383477   31.134402   9.062885   2.589396  0.554871  0.739827    1622
# 716  51.708218   31.578947   3.416436   7.663897  0.092336  0.461681    1083
# 670  52.500000   29.880952   5.714286   6.309524  0.000000  0.238095     840
# 654  53.531599   31.598513   9.169765   2.850062  0.619579  0.000000     807

# %%
sns.pairplot(partii)

# %%
partii.plot.scatter(x='golosa', y=['EDRO'], title=u'Зависимость явки и результатов ЕДРО')

# %%
from statsmodels.graphics.gofplots import qqplot

# %%
qqplot(partii[['EDRO']],dist=sts.norm, line='45', fit=True);
qqplot(partii[['EDRO']], dist=sts.norm, line='q', fit=True);

# %%
qqplot(partii[['SPRAV_RUS']], line='q', fit=True);

# %%
qqplot(partii[['KOMMUNISTY']], line='q', fit=True);

# %%
qqplot(partii[['LDPR']], line='q', fit=True);

# %%
qqplot(partii[['PROSTA']], line='q', fit=True);
